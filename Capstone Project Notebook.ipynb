# %% [markdown]
# # Welcome to the Applied Data Science Capstone Project Notebook

# %% [markdown]
# ## Table of Contents
#
# <a href="#item1">1. Segmenting and Clustering Neighborhoods in Toronto</a>
# <br/>
# <a href="#item11">1.1 Import the neighborhood data into the dataframe grouped by postal codes</a>
# <br/>
# <a href="#item12">1.2 Enrich our DataFrame with geocodes for each postal code of Toronto</a>
# <br/>
# <a href="#item13">1.3 Visualize data of Toronto neighborhoods</a>
# <br/>
# <a href="#item14">1.4 Explore venues of Toronto neighborhoods</a>
# <br/>
# <a href="#item15">1.5 Cluster neighborhoods of Toronto</a>
# <br/>
# <a href="#item16">1.6 Visualize clusters of Toronto neighborhoods</a>

# %% [markdown]
# <a id="item1"></a>
# # 1. Segmenting and Clustering Neighborhoods in Toronto
# <a id="item11"></a>
# ## 1.1 Import the neighborhood data into the dataframe grouped by postal codes

# %% [markdown]
# First we need to import libraries required for web scraping and further data analysis and visualization:

# %%
import pandas as pd # import pandas
import numpy as np # import Numpy

# install BeautifulSoup

# !conda install -c conda-forge beautifulsoup4 --yes
from bs4 import BeautifulSoup

import requests # library to handle HHTP requests

import sys # library to access system functions

import json # library to handle JSON files


# install and import geocoder lib
# !conda install -c conda-forge geocoder --yes
import geocoder # import geocoder

print("Geocoder library loaded.")

# !conda install -c conda-forge folium --yes
import folium # map rendering library

print("Folium library loaded.")

from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# set pandas option to return all rows and columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - beautifulsoup4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-2.11                  |         openblas          10 KB  conda-forge
#     scikit-learn-0.20.1        |   py36h22eb022_0         5.7 MB
#     liblapack-3.8.0            |      11_openblas          10 KB  conda-forge
#     scipy-1.3.2                |   py36h921218d_0        18.0 MB  conda-forge
#     libopenblas-0.3.6          |       h5a2b251_2         7.7 MB
#     liblapacke-3.8.0           |      11_openblas          10 KB  conda-forge
#     numpy-1.17.3               |   py36h95a1406_0         5.2 MB  conda-forge
#     libcblas-3.8.0             |      11_openblas          10 KB  conda-forge
#     libblas-3.8.0              |      11_openblas          10 KB  conda-forge
#     soupsieve-1.9.4            |           py36_0          58 KB  conda-forge
#     beautifulsoup4-4.8.1       |           py36_0         149 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        36.9 MB
#
# The following NEW packages will be INSTALLED:
#
#     libblas:        3.8.0-11_openblas                      conda-forge
#     libcblas:       3.8.0-11_openblas                      conda-forge
#     liblapack:      3.8.0-11_openblas                      conda-forge
#     liblapacke:     3.8.0-11_openblas                      conda-forge
#     libopenblas:    0.3.6-h5a2b251_2
#     soupsieve:      1.9.4-py36_0                           conda-forge
#
# The following packages will be UPDATED:
#
#     beautifulsoup4: 4.6.3-py37_0                                       --> 4.8.1-py36_0          conda-forge
#     blas:           1.1-openblas                           conda-forge --> 2.11-openblas         conda-forge
#     numpy:          1.16.2-py36_blas_openblash1522bff_0    conda-forge [blas_openblas] --> 1.17.3-py36h95a1406_0 conda-forge
#     scipy:          1.2.1-py36_blas_openblash1522bff_0     conda-forge [blas_openblas] --> 1.3.2-py36h921218d_0  conda-forge
#
# The following packages will be DOWNGRADED:
#
#     scikit-learn:   0.20.1-py36_blas_openblashebff5e3_1200 conda-forge [blas_openblas] --> 0.20.1-py36h22eb022_0
#
#
# Downloading and Extracting Packages
# blas-2.11            | 10 KB     | ##################################### | 100%
# scikit-learn-0.20.1  | 5.7 MB    | ##################################### | 100%
# liblapack-3.8.0      | 10 KB     | ##################################### | 100%
# scipy-1.3.2          | 18.0 MB   | ##################################### | 100%
# libopenblas-0.3.6    | 7.7 MB    | ##################################### | 100%
# liblapacke-3.8.0     | 10 KB     | ##################################### | 100%
# numpy-1.17.3         | 5.2 MB    | ##################################### | 100%
# libcblas-3.8.0       | 10 KB     | ##################################### | 100%
# libblas-3.8.0        | 10 KB     | ##################################### | 100%
# soupsieve-1.9.4      | 58 KB     | ##################################### | 100%
# beautifulsoup4-4.8.1 | 149 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geocoder
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     future-0.18.2              |           py36_0         713 KB  conda-forge
#     click-7.0                  |             py_0          61 KB  conda-forge
#     ratelim-0.1.6              |             py_2           6 KB  conda-forge
#     geocoder-1.38.1            |             py_1          53 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         833 KB
#
# The following NEW packages will be INSTALLED:
#
#     future:   0.18.2-py36_0 conda-forge
#     geocoder: 1.38.1-py_1   conda-forge
#     ratelim:  0.1.6-py_2    conda-forge
#
# The following packages will be UPDATED:
#
#     click:    6.7-py37_0                --> 7.0-py_0 conda-forge
#
#
# Downloading and Extracting Packages
# future-0.18.2        | 713 KB    | ##################################### | 100%
# click-7.0            | 61 KB     | ##################################### | 100%
# ratelim-0.1.6        | 6 KB      | ##################################### | 100%
# geocoder-1.38.1      | 53 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Geocoder library loaded.
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - folium
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     folium-0.10.0              |             py_1          59 KB  conda-forge
#
# The following packages will be UPDATED:
#
#     folium: 0.5.0-py_0 conda-forge --> 0.10.0-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# folium-0.10.0        | 59 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium library loaded.

# %% [markdown]
# Then we retrieve (scrape) the postal codes and neighborhoods of Toronto using BeautifulSoup library - ***please note that web scraping may fail in case if the page is not accessible***:

# %%
# retrieve the page using GET request
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M' #'https://ere34t.test'
try:
    response = requests.get(url)
except ConnectionError: 
    print("Error while accessing the webpage  {}\nException:\n{}\n{}".format(url,sys.exc_info()[0],sys.exc_info()[1]))
except:
    print("Error while reading the contents of the webpage {}\nException:\n{}\n{}".format(url,sys.exc_info()[0],sys.exc_info()[1]))
else:
    print("Web page data successfully loaded.")
# Out:
# Web page data successfully loaded.

# %% [markdown]
# Load the data into BS object instance:

# %%
try:
    # load the page contents into BeautifulSoup object instance 
    soup = BeautifulSoup(response.text, "html.parser")

    # find the table rows - the table doesn't contain ID so I started from the DIV tag and locating our table by tag
    table_rows = soup.find('div', id="mw-content-text").table.tbody.find_all("tr")
except TypeError as e: 
    # in case if the current page design changes so that above string couldn't be found then exception shall be catched 
    print("Unable to find the required information on the web page:\n{0}".format(e))
    
else:
    print("Page data has been loaded into BS object.")
# Out:
# Page data has been loaded into BS object.

# %% [markdown]
# Read the scraped table from BS object into the DataFrame:

# %%
header = ['PostalCode', 'Borough', 'Neighborhood']

body = []

try:
    # read tables rows and cells into a list
    for tr in table_rows:
        td = tr.find_all('td')    
        row = [cell.text.rstrip() for cell in td]
        body.append(row)
except:
   print("Error while retrieving the body of the table.\nException details:{0}".format(sys.exc_info()[0])) 
else:
    # Load list data into a data frame
    df = pd.DataFrame(body, columns=header)

    # Replace Not assigned and None values to NaN 
    df.replace(["Not assigned","None"], np.NaN, inplace=True)

    df = df[df[header[1]].notnull()]
    
    df[header[2]].fillna(df[header[1]], inplace=True)
    
    print("DataFrame has been loaded with postal codes of Toronto.")
# Out:
# DataFrame has been loaded with postal codes of Toronto.

# %% [markdown]
# Let's explore our data set - the size and possible duplicates:

# %%
print(df.shape)

df[df.duplicated(['Neighborhood'], keep=False)].sort_values("Neighborhood")
# Out:
# (210, 3)
#     PostalCode           Borough    Neighborhood
# 8          M7A      Queen's Park    Queen's Park
# 10         M9A      Queen's Park    Queen's Park
# 147        M6N              York       Runnymede
# 186        M6S      West Toronto       Runnymede
# 34         M5C  Downtown Toronto  St. James Town
# 250        M4X  Downtown Toronto  St. James Town

# %% [markdown]
# Ok, we found 210 records and 3 possible duplicate records - let's remember their postal codes to highlight them later on the map using different colors:

# %%
possible_duplicates = df[df.duplicated(['Neighborhood'], keep=False)].sort_values("Neighborhood")["PostalCode"].unique()

# %% [markdown]
# Let's define *toronto_data* dataframe - group *dF* dataframe by PostalCode and aggregate the Neighborhood values via concatenation separated by a *comma*:
# <a href="#capstone1"></a>

# %%
toronto_data = (df.groupby(header[0]).agg({header[1]:'first',header[2] : ', '.join}).reset_index().reindex(columns=df.columns))

toronto_data.head()
# Out:
#   PostalCode      Borough                            Neighborhood
# 0        M1B  Scarborough                          Rouge, Malvern
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %% [markdown]
# Let's clarify what happened with our possible duplicate neighborhoods:

# %%
toronto_data[toronto_data.duplicated(['Neighborhood'], keep=False)].sort_values("Neighborhood")
# Out:
#    PostalCode       Borough  Neighborhood
# 85        M7A  Queen's Park  Queen's Park
# 93        M9A  Queen's Park  Queen's Park

# %% [markdown]
# So, we see only one duplicate record, it means the rest were grouped under their postal codes with other neighborhoods.
#
# Show the dimensions of the resulting DataFrame:

# %%
toronto_data.shape
# Out:
# (103, 3)

# %% [markdown]
# <a id="item12"></a>
# ## 1.2 Enrich our DataFrame with geocodes for each postal code of Toronto

# %% [markdown]
# We shall use the *geocoder* library to retrieve geo coordinates for each postal code of Toronto:

# %%
lat_list = []
lng_list = []

# for each row (postal code) in the DataFrame we shall retrieve the coordinates and store them into 2 lists (latitude and longitude)
for row in toronto_data.itertuples(index=False):
    # set lat_lng_coords to None before while iteration
    lat_lng_coords = None
    while(lat_lng_coords is None):
        g = geocoder.arcgis('{}, Toronto, Ontario'.format(row[0]))
        lat_lng_coords = g.latlng
                
        lat_list.append(lat_lng_coords[0]) 
        lng_list.append(lat_lng_coords[1]) 

# create 2 new columns in our DataFrame and assign them with the lists
toronto_data["Latitude"]=lat_list
toronto_data["Longitude"]=lng_list

toronto_data.head()
# Out:
#   PostalCode      Borough                            Neighborhood   Latitude  \
# 0        M1B  Scarborough                          Rouge, Malvern  43.811525
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.785665
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.765815
# 3        M1G  Scarborough                                  Woburn  43.768369
# 4        M1H  Scarborough                               Cedarbrae  43.769688
#
#    Longitude
# 0 -79.195517
# 1 -79.158725
# 2 -79.175193
# 3 -79.217590
# 4 -79.239440

# %% [markdown]
# Let's check the dimensions - I expect 103x5:

# %%
toronto_data.shape
# Out:
# (103, 5)

# %% [markdown]
# <a id="item13"></a>
# ## 1.3 Visualize data of Toronto neighborhoods

# %% [markdown]
# Let's discover our neighborhood data together with *possible_duplicates* on the map. Possible duplicate records shall be colored in red:

# %%
# create map of Toronto using latitude and longitude values
latitude = 43.651070
longitude = -79.347015

map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10, height=500)

# add markers to map
for lat, lng, borough, neighborhood, postalcode in zip(toronto_data['Latitude'], toronto_data['Longitude'], toronto_data['Borough'], toronto_data['Neighborhood'], toronto_data["PostalCode"]):
    label = folium.Popup("{} {}".format(postalcode, neighborhood), parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=3,
        popup=label,
        color= ('red' if postalcode in possible_duplicates else 'blue'),
        fill=True,
        fill_color= ('red' if postalcode in possible_duplicates else 'blue'),
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  

map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Let's check possible duplicate neighborhoods highlighted with red circles:
# 1) **Queen's Park** neighborhood spans across 2 different locations. M7A located close to the Queen's Park place, but M9A located in Etobicoke which is quite far from the Queen's Park. Seems it's an error in Wikipedia page - the true location of this postal code belongs to **Humber Valley Village** neighborhood - https://en.wikipedia.org/wiki/Humber_Valley_Village. We shall correct the data in the dataframe to reflect the same.
# <br/>
# 2) **Runnymede** neighborhood spans across 2 different postal codes. Let's check if that's true using Wikipedia and Google Maps (https://en.wikipedia.org/wiki/Runnymede,_Toronto): this neighborhood located between Annette St in the south and Dundas St West in the north. The only postal code for this area is M6S. The other one lies to the north of Runnymede which might be an error in Wikipedia page. Let's remove mention of Runnymede from M6N postal code.
# <br/>
# 3) **St. James Town** - as per Wiki page located across 2 postal codes but a quick research shows that St. James Town has M4X postal code. The other one is in the heart of Old Toronto nearby St. James Park - again I suspect an error in Wikipedia data. Let's correct M5C data with **St James Park** as a name of the neighborhood - by analogy with Queen's Park toponym above.

# %%
toronto_data.loc[toronto_data["PostalCode"]=="M9A",["Borough","Neighborhood"]] = ["Etobicoke","Humber Valley Village"]
toronto_data.loc[toronto_data["PostalCode"]=="M6N", "Neighborhood"] = "The Junction North"
toronto_data.loc[toronto_data["PostalCode"]=="M5C", "Neighborhood"] = "St James Park"

toronto_data.loc[toronto_data["PostalCode"].isin(possible_duplicates)].head(6)
# Out:
#    PostalCode           Borough                 Neighborhood   Latitude  \
# 51        M4X  Downtown Toronto  Cabbagetown, St. James Town  43.668160
# 55        M5C  Downtown Toronto                St James Park  43.651210
# 81        M6N              York           The Junction North  43.676125
# 84        M6S      West Toronto           Runnymede, Swansea  43.649620
# 85        M7A      Queen's Park                 Queen's Park  43.661150
# 93        M9A         Etobicoke        Humber Valley Village  43.662299
#
#     Longitude
# 51 -79.366602
# 55 -79.375481
# 81 -79.481932
# 84 -79.476141
# 85 -79.391715
# 93 -79.528195

# %% [markdown]
# Now it looks better - all possibly duplicated neighborhoods aligned with their postal codes.

# %% [markdown]
# <a id="item14"></a>
# ## 1.4 Explore venues of Toronto neighborhoods

# %% [markdown]
# In order to explore venues of Toronto let's define the Foursquare client's ID and secret as well as the API version:

# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# Let's borrow getNearbyVenues from the course lab with the slight modification - print out the location without any venues found:

# %%
def getNearbyVenues(postalcodes, names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for postalcode, name, lat, lng in zip(postalcodes, names, latitudes, longitudes):
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        if not results:
            print("{} {} has no venues".format(postalcode, name))
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            postalcode,
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
        
    nearby_venues.columns = [
                  'PostalCode',
                  'Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# Let's call the code using the function defined above:

# %%
toronto_venues = getNearbyVenues(postalcodes=toronto_data['PostalCode'],
                                   names=toronto_data['Neighborhood'],
                                   latitudes=toronto_data['Latitude'],
                                   longitudes=toronto_data['Longitude']
                                  )
# Out:
# M1X Upper Rouge has no venues
# M2L Silver Hills, York Mills has no venues
# M5N Roselawn has no venues

# %% [markdown]
# Let's note that 3 postal codes have no venues - later on we'll mark them with separate cluster.
#
# Let's explore the *toronto_venues* dataframe:

# %%
toronto_venues.head()
# Out:
#   PostalCode                            Neighborhood  Neighborhood Latitude  \
# 0        M1B                          Rouge, Malvern              43.811525
# 1        M1C  Highland Creek, Rouge Hill, Port Union              43.785665
# 2        M1E       Guildwood, Morningside, West Hill              43.765815
# 3        M1E       Guildwood, Morningside, West Hill              43.765815
# 4        M1E       Guildwood, Morningside, West Hill              43.765815
#
#    Neighborhood Longitude                             Venue  Venue Latitude  \
# 0              -79.195517  Canadian Appliance Source Whitby       43.808353
# 1              -79.158725             Royal Canadian Legion       43.782533
# 2              -79.175193          Homestead Roofing Repair       43.765140
# 3              -79.175193       Heron Park Community Centre       43.768867
# 4              -79.175193                        Heron Park       43.769327
#
#    Venue Longitude              Venue Category
# 0       -79.191331                Home Service
# 1       -79.163085                         Bar
# 2       -79.178663  Construction & Landscaping
# 3       -79.176958        Gym / Fitness Center
# 4       -79.177201                        Park

# %%
unique_categories = toronto_venues['Venue Category'].unique()
print('There are {} uniques categories.'.format(len(unique_categories)))
# Out:
# There are 262 uniques categories.

# %% [markdown]
# Let's check the list of categories:

# %%
unique_categories.sort()

print(unique_categories)
# Out:
# ['Afghan Restaurant' 'Airport' 'American Restaurant' 'Antique Shop'
#  'Argentinian Restaurant' 'Art Gallery' 'Arts & Crafts Store'
#  'Asian Restaurant' 'Athletics & Sports' 'Auto Dealership' 'Auto Garage'
#  'BBQ Joint' 'Baby Store' 'Bagel Shop' 'Bakery' 'Bank' 'Bar'
#  'Basketball Court' 'Basketball Stadium' 'Bed & Breakfast' 'Beer Bar'
#  'Beer Store' 'Belgian Restaurant' 'Bike Shop' 'Bistro' 'Boat or Ferry'
#  'Bookstore' 'Boutique' 'Brazilian Restaurant' 'Breakfast Spot' 'Brewery'
#  'Bridge' 'Bubble Tea Shop' 'Buffet' 'Building' 'Burger Joint'
#  'Burrito Place' 'Bus Line' 'Bus Station' 'Bus Stop' 'Business Service'
#  'Butcher' 'Cafeteria' 'Café' 'Candy Store' 'Caribbean Restaurant'
#  'Carpet Store' 'Cheese Shop' 'Chinese Restaurant' 'Chocolate Shop'
#  'Church' 'Clothing Store' 'Cocktail Bar' 'Coffee Shop'
#  'College Arts Building' 'College Auditorium' 'College Cafeteria'
#  'College Gym' 'College Rec Center' 'College Stadium'
#  'Colombian Restaurant' 'Comfort Food Restaurant' 'Comic Shop'
#  'Concert Hall' 'Construction & Landscaping' 'Convenience Store'
#  'Cosmetics Shop' 'Creperie' 'Cuban Restaurant' 'Cupcake Shop'
#  'Dance Studio' 'Deli / Bodega' 'Department Store' 'Dessert Shop'
#  'Dim Sum Restaurant' 'Diner' 'Discount Store' "Doctor's Office" 'Dog Run'
#  'Donut Shop' 'Dumpling Restaurant' 'Eastern European Restaurant'
#  'Electronics Store' 'Ethiopian Restaurant' 'Event Space'
#  'Falafel Restaurant' 'Farm' 'Farmers Market' 'Fast Food Restaurant'
#  'Field' 'Filipino Restaurant' 'Fish & Chips Shop' 'Fish Market'
#  'Flea Market' 'Flower Shop' 'Food' 'Food & Drink Shop' 'Food Court'
#  'Food Stand' 'Food Truck' 'Fountain' 'French Restaurant'
#  'Fried Chicken Joint' 'Frozen Yogurt Shop' 'Fruit & Vegetable Store'
#  'Furniture / Home Store' 'Gaming Cafe' 'Garden' 'Gas Station' 'Gastropub'
#  'Gay Bar' 'General Entertainment' 'General Travel' 'Gift Shop'
#  'Gluten-free Restaurant' 'Golf Course' 'Gourmet Shop' 'Greek Restaurant'
#  'Grocery Store' 'Gym' 'Gym / Fitness Center' 'Gym Pool' 'Harbor / Marina'
#  'Hardware Store' 'Health & Beauty Service' 'Health Food Store'
#  'Historic Site' 'History Museum' 'Hobby Shop' 'Hockey Arena'
#  'Home Service' 'Hong Kong Restaurant' 'Hookah Bar' 'Hostel' 'Hotel'
#  'Hotel Bar' 'Hotpot Restaurant' 'Ice Cream Shop' 'Indian Restaurant'
#  'Indonesian Restaurant' 'Intersection' 'Irish Pub' 'Italian Restaurant'
#  'Japanese Restaurant' 'Jazz Club' 'Jewelry Store' 'Juice Bar'
#  'Karaoke Bar' 'Kitchen Supply Store' 'Korean Restaurant' 'Lake'
#  'Latin American Restaurant' 'Lawyer' 'Leather Goods Store'
#  'Light Rail Station' 'Lingerie Store' 'Liquor Store' 'Lounge'
#  'Mac & Cheese Joint' 'Malay Restaurant' 'Market' 'Massage Studio'
#  'Mattress Store' 'Mediterranean Restaurant' "Men's Store" 'Metro Station'
#  'Mexican Restaurant' 'Middle Eastern Restaurant' 'Miscellaneous Shop'
#  'Modern European Restaurant' 'Molecular Gastronomy Restaurant'
#  'Monument / Landmark' 'Movie Theater' 'Museum' 'Music Store'
#  'Music Venue' 'Neighborhood' 'New American Restaurant' 'Nightclub'
#  'Noodle House' 'Office' 'Opera House' 'Optical Shop' 'Organic Grocery'
#  'Other Great Outdoors' 'Park' 'Performing Arts Venue'
#  'Peruvian Restaurant' 'Pet Store' 'Pharmacy' 'Pier' 'Pilates Studio'
#  'Pizza Place' 'Platform' 'Playground' 'Plaza' 'Poke Place' 'Pool'
#  'Portuguese Restaurant' 'Poutine Place' 'Pub' 'Ramen Restaurant'
#  'Record Shop' 'Rental Car Location'
#  'Residential Building (Apartment / Condo)' 'Restaurant'
#  'Rock Climbing Spot' 'Sake Bar' 'Salad Place' 'Salon / Barbershop'
#  'Sandwich Place' 'Sculpture Garden' 'Seafood Restaurant'
#  'Shanghai Restaurant' 'Shoe Store' 'Shopping Mall' 'Skating Rink'
#  'Ski Chalet' 'Smoke Shop' 'Smoothie Shop' 'Snack Place' 'Soccer Field'
#  'Soup Place' 'Southern / Soul Food Restaurant' 'Spa' 'Speakeasy'
#  'Sporting Goods Shop' 'Sports Bar' 'Sports Club' 'Stationery Store'
#  'Steakhouse' 'Storage Facility' 'Strip Club' 'Supermarket'
#  'Supplement Shop' 'Sushi Restaurant' 'Swim School' 'Taco Place'
#  'Tailor Shop' 'Taiwanese Restaurant' 'Tanning Salon' 'Tapas Restaurant'
#  'Tea Room' 'Tech Startup' 'Tennis Court' 'Thai Restaurant' 'Theater'
#  'Theme Restaurant' 'Thrift / Vintage Store' 'Toy / Game Store' 'Trail'
#  'Train Station' 'Tram Station' 'Vegetarian / Vegan Restaurant'
#  'Video Game Store' 'Video Store' 'Vietnamese Restaurant' 'Wine Bar'
#  'Wine Shop' 'Wings Joint' "Women's Store" 'Yoga Studio']

# %% [markdown]
# As we can see there is a category named **Neighborhood** - let's explore what's there and how it can contribute to our analysis:

# %%
toronto_venues[toronto_venues["Venue Category"]=="Neighborhood"].shape

toronto_venues[toronto_venues["Venue Category"]=="Neighborhood"].head()
# Out:
#      PostalCode              Neighborhood  Neighborhood Latitude  \
# 314         M4E               The Beaches              43.676531
# 390         M4M           Studio District              43.660629
# 930         M5G        Central Bay Street              43.656091
# 1086        M5H  Adelaide, King, Richmond              43.649700
#
#       Neighborhood Longitude             Venue  Venue Latitude  \
# 314               -79.295425     Upper Beaches       43.680563
# 390               -79.334855       Leslieville       43.662070
# 930               -79.384930  Downtown Toronto       43.653232
# 1086              -79.382582  Downtown Toronto       43.653232
#
#       Venue Longitude Venue Category
# 314        -79.292869   Neighborhood
# 390        -79.337856   Neighborhood
# 930        -79.385296   Neighborhood
# 1086       -79.385296   Neighborhood

# %%
toronto_data[toronto_data["PostalCode"].isin(["M4E", "M4M", "M5G", "M5H"])].head()
# Out:
#    PostalCode           Borough              Neighborhood   Latitude  \
# 37        M4E      East Toronto               The Beaches  43.676531
# 43        M4M      East Toronto           Studio District  43.660629
# 57        M5G  Downtown Toronto        Central Bay Street  43.656091
# 58        M5H  Downtown Toronto  Adelaide, King, Richmond  43.649700
#
#     Longitude
# 37 -79.295425
# 43 -79.334855
# 57 -79.384930
# 58 -79.382582

# %% [markdown]
# This category doesn't bring any value to our analysis because we already have Neighborhood data. Let's drop this category:

# %%
toronto_venues.drop(toronto_venues[toronto_venues["Venue Category"]=="Neighborhood"].index, inplace=True)

# %% [markdown]
# After we dropped the category there should be 261 unique categories:

# %%
unique_categories = toronto_venues['Venue Category'].unique()
print('There are {} uniques categories.'.format(len(unique_categories)))
# Out:
# There are 261 uniques categories.

# %% [markdown]
# Let's create a one hot encoding dataframe by 'Venue Category' and group the data by PostalCode and Neighborhood calculating the mean value, e.g. frequency of each category per PostalCode:

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add postal code and neighborhood column back to dataframe
toronto_onehot['PostalCode'] = toronto_venues['PostalCode'] 
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood']

toronto_grouped = toronto_onehot.groupby(['PostalCode','Neighborhood']).mean().reset_index()


toronto_grouped
# Out:
#    PostalCode                                       Neighborhood  \
# 0         M1B                                     Rouge, Malvern
# 1         M1C             Highland Creek, Rouge Hill, Port Union
# 2         M1E                  Guildwood, Morningside, West Hill
# 3         M1G                                             Woburn
# 4         M1H                                          Cedarbrae
# 5         M1J                                Scarborough Village
# 6         M1K        East Birchmount Park, Ionview, Kennedy Park
# 7         M1L                    Clairlea, Golden Mile, Oakridge
# 8         M1M    Cliffcrest, Cliffside, Scarborough Village West
# 9         M1N                        Birch Cliff, Cliffside West
# 10        M1P  Dorset Park, Scarborough Town Centre, Wexford ...
# 11        M1R                                  Maryvale, Wexford
# 12        M1S                                          Agincourt
# 13        M1T            Clarks Corners, Sullivan, Tam O'Shanter
# 14        M1V  Agincourt North, L'Amoreaux East, Milliken, St...
# 15        M1W                                    L'Amoreaux West
# 16        M2H                                  Hillcrest Village
# 17        M2J                       Fairview, Henry Farm, Oriole
# 18        M2K                                    Bayview Village
# 19        M2M                            Newtonbrook, Willowdale
# 20        M2N                                   Willowdale South
# 21        M2P                                    York Mills West
# 22        M2R                                    Willowdale West
# 23        M3A                                          Parkwoods
# 24        M3B                                    Don Mills North
# 25        M3C                   Flemingdon Park, Don Mills South
# 26        M3H    Bathurst Manor, Downsview North, Wilson Heights
# 27        M3J                    Northwood Park, York University
# 28        M3K                        CFB Toronto, Downsview East
# 29        M3L                                     Downsview West
# 30        M3M                                  Downsview Central
# 31        M3N                                Downsview Northwest
# 32        M4A                                   Victoria Village
# 33        M4B                    Woodbine Gardens, Parkview Hill
# 34        M4C                                   Woodbine Heights
# 35        M4E                                        The Beaches
# 36        M4G                                            Leaside
# 37        M4H                                   Thorncliffe Park
# 38        M4J                                       East Toronto
# 39        M4K                       The Danforth West, Riverdale
# 40        M4L                     The Beaches West, India Bazaar
# 41        M4M                                    Studio District
# 42        M4N                                      Lawrence Park
# 43        M4P                                   Davisville North
# 44        M4R                                 North Toronto West
# 45        M4S                                         Davisville
# 46        M4T                        Moore Park, Summerhill East
# 47        M4V  Deer Park, Forest Hill SE, Rathnelly, South Hi...
# 48        M4W                                           Rosedale
# 49        M4X                        Cabbagetown, St. James Town
# 50        M4Y                               Church and Wellesley
# 51        M5A                                       Harbourfront
# 52        M5B                           Ryerson, Garden District
# 53        M5C                                      St James Park
# 54        M5E                                        Berczy Park
# 55        M5G                                 Central Bay Street
# 56        M5H                           Adelaide, King, Richmond
# 57        M5J  Harbourfront East, Toronto Islands, Union Station
# 58        M5K           Design Exchange, Toronto Dominion Centre
# 59        M5L                     Commerce Court, Victoria Hotel
# 60        M5M                  Bedford Park, Lawrence Manor East
# 61        M5P                Forest Hill North, Forest Hill West
# 62        M5R                The Annex, North Midtown, Yorkville
# 63        M5S                     Harbord, University of Toronto
# 64        M5T          Chinatown, Grange Park, Kensington Market
# 65        M5V  CN Tower, Bathurst Quay, Island airport, Harbo...
# 66        M5W                    Stn A PO Boxes 25 The Esplanade
# 67        M5X             First Canadian Place, Underground city
# 68        M6A                   Lawrence Heights, Lawrence Manor
# 69        M6B                                          Glencairn
# 70        M6C                                 Humewood-Cedarvale
# 71        M6E                                Caledonia-Fairbanks
# 72        M6G                                           Christie
# 73        M6H                       Dovercourt Village, Dufferin
# 74        M6J                           Little Portugal, Trinity
# 75        M6K       Brockton, Exhibition Place, Parkdale Village
# 76        M6L                 Downsview, North Park, Upwood Park
# 77        M6M     Del Ray, Keelesdale, Mount Dennis, Silverthorn
# 78        M6N                                 The Junction North
# 79        M6P                      High Park, The Junction South
# 80        M6R                             Parkdale, Roncesvalles
# 81        M6S                                 Runnymede, Swansea
# 82        M7A                                       Queen's Park
# 83        M7R              Canada Post Gateway Processing Centre
# 84        M7Y  Business Reply Mail Processing Centre 969 Eastern
# 85        M8V       Humber Bay Shores, Mimico South, New Toronto
# 86        M8W                             Alderwood, Long Branch
# 87        M8X      The Kingsway, Montgomery Road, Old Mill North
# 88        M8Y  Humber Bay, King's Mill Park, Kingsway Park So...
# 89        M8Z  Kingsway Park South West, Mimico NW, The Queen...
# 90        M9A                              Humber Valley Village
# 91        M9B  Cloverdale, Islington, Martin Grove, Princess ...
# 92        M9C  Bloordale Gardens, Eringate, Markland Wood, Ol...
# 93        M9L                                      Humber Summit
# 94        M9M                                   Emery, Humberlea
# 95        M9N                                             Weston
# 96        M9P                                          Westmount
# 97        M9R  Kingsview Village, Martin Grove Gardens, Richv...
# 98        M9V  Albion Gardens, Beaumond Heights, Humbergate, ...
# 99        M9W                                          Northwest
#
#     Afghan Restaurant  Airport  American Restaurant  Antique Shop  \
# 0            0.000000     0.00             0.000000       0.00000
# 1            0.000000     0.00             0.000000       0.00000
# 2            0.000000     0.00             0.000000       0.00000
# 3            0.000000     0.00             0.000000       0.00000
# 4            0.000000     0.00             0.000000       0.00000
# 5            0.000000     0.00             0.000000       0.00000
# 6            0.000000     0.00             0.000000       0.00000
# 7            0.000000     0.00             0.000000       0.00000
# 8            0.000000     0.00             0.000000       0.00000
# 9            0.000000     0.00             0.000000       0.00000
# 10           0.000000     0.00             0.000000       0.00000
# 11           0.000000     0.00             0.000000       0.00000
# 12           0.000000     0.00             0.000000       0.00000
# 13           0.000000     0.00             0.000000       0.00000
# 14           0.000000     0.00             0.000000       0.00000
# 15           0.000000     0.00             0.000000       0.00000
# 16           0.000000     0.00             0.000000       0.00000
# 17           0.000000     0.00             0.000000       0.00000
# 18           0.000000     0.00             0.000000       0.00000
# 19           0.000000     0.00             0.000000       0.00000
# 20           0.000000     0.00             0.033333       0.00000
# 21           0.000000     0.00             0.000000       0.00000
# 22           0.000000     0.00             0.000000       0.00000
# 23           0.000000     0.00             0.000000       0.00000
# 24           0.000000     0.00             0.000000       0.00000
# 25           0.000000     0.00             0.000000       0.00000
# 26           0.000000     0.00             0.000000       0.00000
# 27           0.000000     0.00             0.000000       0.00000
# 28           0.000000     0.25             0.000000       0.00000
# 29           0.000000     0.00             0.000000       0.00000
# 30           0.000000     0.00             0.000000       0.00000
# 53       0.000000     0.000000
# 54       0.000000     0.000000
# 55       0.000000     0.000000
# 56       0.000000     0.000000
# 57       0.000000     0.000000
# 58       0.000000     0.000000
# 59       0.000000     0.000000
# 60       0.000000     0.000000
# 61       0.000000     0.000000
# 62       0.000000     0.000000
# 63       0.000000     0.000000
# 64       0.000000     0.000000
# 65       0.000000     0.014493
# 66       0.000000     0.000000
# 67       0.000000     0.000000
# 68       0.000000     0.000000
# 69       0.000000     0.000000
# 70       0.000000     0.000000
# 71       0.100000     0.000000
# 72       0.000000     0.000000
# 73       0.000000     0.000000
# 74       0.000000     0.015873
# 75       0.000000     0.000000
# 76       0.000000     0.000000
# 77       0.000000     0.000000
# 78       0.000000     0.000000
# 79       0.000000     0.000000
# 80       0.000000     0.000000
# 81       0.000000     0.000000
# 82       0.000000     0.000000
# 83       0.000000     0.000000
# 84       0.000000     0.000000
# 85       0.000000     0.000000
# 86       0.000000     0.000000
# 87       0.000000     0.000000
# 88       0.000000     0.000000
# 89       0.000000     0.000000
# 90       0.000000     0.000000
# 91       0.000000     0.000000
# 92       0.000000     0.000000
# 93       0.000000     0.000000
# 94       0.000000     0.000000
# 95       0.000000     0.000000
# 96       0.000000     0.000000
# 97       0.000000     0.000000
# 98       0.000000     0.000000
# 99       0.000000     0.000000

# %%
toronto_onehot.shape
# Out:
# (2468, 263)

# %%
toronto_grouped.shape
# Out:
# (100, 263)

# %% [markdown]
# Let's borrow *return_most_common_venues* function from our course lab - it will return *n-* most frequent venue types per each postal code:

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[2:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['PostalCode','Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['PostalCode'] = toronto_grouped['PostalCode']
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 2:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#   PostalCode                            Neighborhood  \
# 0        M1B                          Rouge, Malvern
# 1        M1C  Highland Creek, Rouge Hill, Port Union
# 2        M1E       Guildwood, Morningside, West Hill
# 3        M1G                                  Woburn
# 4        M1H                               Cedarbrae
#
#         1st Most Common Venue 2nd Most Common Venue  \
# 0                Home Service     Food & Drink Shop
# 1                         Bar           Yoga Studio
# 2  Construction & Landscaping  Gym / Fitness Center
# 3            Business Service     Korean Restaurant
# 4                  Playground                Lounge
#
#          3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0                  Flower Shop           Flea Market           Fish Market
# 1                         Food           Flower Shop           Flea Market
# 2                         Park  Ethiopian Restaurant           Event Space
# 3                 Soccer Field           Coffee Shop                  Park
# 4  Eastern European Restaurant           Flower Shop           Flea Market
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0     Fish & Chips Shop   Filipino Restaurant                 Field
# 1           Fish Market     Fish & Chips Shop   Filipino Restaurant
# 2    Falafel Restaurant                  Farm        Farmers Market
# 3  Fast Food Restaurant           Event Space    Falafel Restaurant
# 4           Fish Market     Fish & Chips Shop   Filipino Restaurant
#
#   9th Most Common Venue       10th Most Common Venue
# 0  Fast Food Restaurant               Farmers Market
# 1                 Field         Fast Food Restaurant
# 2  Fast Food Restaurant  Eastern European Restaurant
# 3                  Farm               Farmers Market
# 4                 Field         Fast Food Restaurant

# %% [markdown]
# <a id="item15"></a>
# ## 1.5 Cluster neighborhoods of Toronto

# %% [markdown]
# Let's split the neighborhoods in 6 clusters - the 6th cluster will consist of those neighborhoods which don't have any venues return from Foursquare API. We shall use KMean data clusterization algorithm from sclearn library:

# %%
# set number of clusters to 5
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop(['PostalCode','Neighborhood'], 1)

toronto_grouped_clustering.head()

# run k-means clustering
kmeans = KMeans(init='k-means++', n_clusters=kclusters, random_state=0,n_init=1000).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([2, 0, 4, 4, 0, 0, 0, 0, 0, 4], dtype=int32)

# %% [markdown]
# Let's add the results of clustering to the initial cleaned data of Toronto neighborhoods and call it *toronto_merged* dataframe:

# %%
# add clustering labels
if 'Cluster Labels' in neighborhoods_venues_sorted.columns:
    neighborhoods_venues_sorted['Cluster Labels']=kmeans.labels_
else:
    neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = toronto_data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index(['PostalCode','Neighborhood']), on=['PostalCode','Neighborhood'])

toronto_merged.head() # check the last columns!
# Out:
#   PostalCode      Borough                            Neighborhood   Latitude  \
# 0        M1B  Scarborough                          Rouge, Malvern  43.811525
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.785665
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.765815
# 3        M1G  Scarborough                                  Woburn  43.768369
# 4        M1H  Scarborough                               Cedarbrae  43.769688
#
#    Longitude  Cluster Labels       1st Most Common Venue  \
# 0 -79.195517             2.0                Home Service
# 1 -79.158725             0.0                         Bar
# 2 -79.175193             4.0  Construction & Landscaping
# 3 -79.217590             4.0            Business Service
# 4 -79.239440             0.0                  Playground
#
#   2nd Most Common Venue        3rd Most Common Venue 4th Most Common Venue  \
# 0     Food & Drink Shop                  Flower Shop           Flea Market
# 1           Yoga Studio                         Food           Flower Shop
# 2  Gym / Fitness Center                         Park  Ethiopian Restaurant
# 3     Korean Restaurant                 Soccer Field           Coffee Shop
# 4                Lounge  Eastern European Restaurant           Flower Shop
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0           Fish Market     Fish & Chips Shop   Filipino Restaurant
# 1           Flea Market           Fish Market     Fish & Chips Shop
# 2           Event Space    Falafel Restaurant                  Farm
# 3                  Park  Fast Food Restaurant           Event Space
# 4           Flea Market           Fish Market     Fish & Chips Shop
#
#   8th Most Common Venue 9th Most Common Venue       10th Most Common Venue
# 0                 Field  Fast Food Restaurant               Farmers Market
# 1   Filipino Restaurant                 Field         Fast Food Restaurant
# 2        Farmers Market  Fast Food Restaurant  Eastern European Restaurant
# 3    Falafel Restaurant                  Farm               Farmers Market
# 4   Filipino Restaurant                 Field         Fast Food Restaurant

# %% [markdown]
# How many examples fall into each cluster?

# %%
toronto_merged.groupby("Cluster Labels").size()
# Out:
# Cluster Labels
# 0.0    74
# 1.0     1
# 2.0     3
# 3.0     1
# 4.0    21
# dtype: int64

# %% [markdown]
# <br/>
# Remember that we have NaN cluster labels after merge - there should be 3 records w/o any venues found on FourSquare:

# %%
toronto_merged[pd.isnull(toronto_merged).any(axis=1)].head()
# Out:
#    PostalCode          Borough              Neighborhood   Latitude  \
# 16        M1X      Scarborough               Upper Rouge  43.834215
# 20        M2L       North York  Silver Hills, York Mills  43.757095
# 63        M5N  Central Toronto                  Roselawn  43.711941
#
#     Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 16 -79.216701             NaN                   NaN                   NaN
# 20 -79.380320             NaN                   NaN                   NaN
# 63 -79.419120             NaN                   NaN                   NaN
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 16                   NaN                   NaN                   NaN
# 20                   NaN                   NaN                   NaN
# 63                   NaN                   NaN                   NaN
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 16                   NaN                   NaN                   NaN
# 20                   NaN                   NaN                   NaN
# 63                   NaN                   NaN                   NaN
#
#    9th Most Common Venue 10th Most Common Venue
# 16                   NaN                    NaN
# 20                   NaN                    NaN
# 63                   NaN                    NaN

# %% [markdown]
# As expected 3 records found - let's mark these records with Cluster = 5 (the numbering starts from 0):

# %%
toronto_merged.loc[pd.isnull(toronto_merged).any(axis=1),"Cluster Labels"] = kclusters
toronto_merged.head()
# Out:
#   PostalCode      Borough                            Neighborhood   Latitude  \
# 0        M1B  Scarborough                          Rouge, Malvern  43.811525
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.785665
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.765815
# 3        M1G  Scarborough                                  Woburn  43.768369
# 4        M1H  Scarborough                               Cedarbrae  43.769688
#
#    Longitude  Cluster Labels       1st Most Common Venue  \
# 0 -79.195517             2.0                Home Service
# 1 -79.158725             0.0                         Bar
# 2 -79.175193             4.0  Construction & Landscaping
# 3 -79.217590             4.0            Business Service
# 4 -79.239440             0.0                  Playground
#
#   2nd Most Common Venue        3rd Most Common Venue 4th Most Common Venue  \
# 0     Food & Drink Shop                  Flower Shop           Flea Market
# 1           Yoga Studio                         Food           Flower Shop
# 2  Gym / Fitness Center                         Park  Ethiopian Restaurant
# 3     Korean Restaurant                 Soccer Field           Coffee Shop
# 4                Lounge  Eastern European Restaurant           Flower Shop
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0           Fish Market     Fish & Chips Shop   Filipino Restaurant
# 1           Flea Market           Fish Market     Fish & Chips Shop
# 2           Event Space    Falafel Restaurant                  Farm
# 3                  Park  Fast Food Restaurant           Event Space
# 4           Flea Market           Fish Market     Fish & Chips Shop
#
#   8th Most Common Venue 9th Most Common Venue       10th Most Common Venue
# 0                 Field  Fast Food Restaurant               Farmers Market
# 1   Filipino Restaurant                 Field         Fast Food Restaurant
# 2        Farmers Market  Fast Food Restaurant  Eastern European Restaurant
# 3    Falafel Restaurant                  Farm               Farmers Market
# 4   Filipino Restaurant                 Field         Fast Food Restaurant

# %% [markdown]
# <a id="item16"></a>
# ## 1.6 Visualize clusters of Toronto neighborhoods

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=10)

# set color scheme for the clusters
rainbow = ['red','orange','yellow','green','blue','purple']

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=2,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Cluster 1

# %%
cluster1 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[0,2] + list(range(6, toronto_merged.shape[1]))]]

cluster1
# Out:
#     PostalCode                                       Neighborhood  \
# 1          M1C             Highland Creek, Rouge Hill, Port Union
# 4          M1H                                          Cedarbrae
# 5          M1J                                Scarborough Village
# 6          M1K        East Birchmount Park, Ionview, Kennedy Park
# 7          M1L                    Clairlea, Golden Mile, Oakridge
# 8          M1M    Cliffcrest, Cliffside, Scarborough Village West
# 10         M1P  Dorset Park, Scarborough Town Centre, Wexford ...
# 11         M1R                                  Maryvale, Wexford
# 12         M1S                                          Agincourt
# 13         M1T            Clarks Corners, Sullivan, Tam O'Shanter
# 14         M1V  Agincourt North, L'Amoreaux East, Milliken, St...
# 15         M1W                                    L'Amoreaux West
# 17         M2H                                  Hillcrest Village
# 18         M2J                       Fairview, Henry Farm, Oriole
# 21         M2M                            Newtonbrook, Willowdale
# 22         M2N                                   Willowdale South
# 24         M2R                                    Willowdale West
# 27         M3C                   Flemingdon Park, Don Mills South
# 29         M3J                    Northwood Park, York University
# 31         M3L                                     Downsview West
# 33         M3N                                Downsview Northwest
# 35         M4B                    Woodbine Gardens, Parkview Hill
# 36         M4C                                   Woodbine Heights
# 37         M4E                                        The Beaches
# 38         M4G                                            Leaside
# 39         M4H                                   Thorncliffe Park
# 42         M4L                     The Beaches West, India Bazaar
# 43         M4M                                    Studio District
# 44         M4N                                      Lawrence Park
# 45         M4P                                   Davisville North
# 47         M4S                                         Davisville
# 49         M4V  Deer Park, Forest Hill SE, Rathnelly, South Hi...
# 51         M4X                        Cabbagetown, St. James Town
# 52         M4Y                               Church and Wellesley
# 53         M5A                                       Harbourfront
# 54         M5B                           Ryerson, Garden District
# 55         M5C                                      St James Park
# 56         M5E                                        Berczy Park
# 57         M5G                                 Central Bay Street
# 58         M5H                           Adelaide, King, Richmond
# 60         M5K           Design Exchange, Toronto Dominion Centre
# 61         M5L                     Commerce Court, Victoria Hotel
# 62         M5M                  Bedford Park, Lawrence Manor East
# 65         M5R                The Annex, North Midtown, Yorkville
# 66         M5S                     Harbord, University of Toronto
# 67         M5T          Chinatown, Grange Park, Kensington Market
# 68         M5V  CN Tower, Bathurst Quay, Island airport, Harbo...
# 69         M5W                    Stn A PO Boxes 25 The Esplanade
# 70         M5X             First Canadian Place, Underground city
# 71         M6A                   Lawrence Heights, Lawrence Manor
# 72         M6B                                          Glencairn
# 73         M6C                                 Humewood-Cedarvale
# 75         M6G                                           Christie
# 76         M6H                       Dovercourt Village, Dufferin
# 77         M6J                           Little Portugal, Trinity
# 78         M6K       Brockton, Exhibition Place, Parkdale Village
# 80         M6M     Del Ray, Keelesdale, Mount Dennis, Silverthorn
# 81         M6N                                 The Junction North
# 83         M6R                             Parkdale, Roncesvalles
# 84         M6S                                 Runnymede, Swansea
# 85         M7A                                       Queen's Park
# 86         M7R              Canada Post Gateway Processing Centre
# 87         M7Y  Business Reply Mail Processing Centre 969 Eastern
# 88         M8V       Humber Bay Shores, Mimico South, New Toronto
# 89         M8W                             Alderwood, Long Branch
# 91         M8Y  Humber Bay, King's Mill Park, Kingsway Park So...
# 92         M8Z  Kingsway Park South West, Mimico NW, The Queen...
# 93         M9A                              Humber Valley Village
# 95         M9C  Bloordale Gardens, Eringate, Markland Wood, Ol...
# 98         M9N                                             Weston
# 99         M9P                                          Westmount
# 100        M9R  Kingsview Village, Martin Grove Gardens, Richv...
# 101        M9V  Albion Gardens, Beaumond Heights, Humbergate, ...
# 102        M9W                                          Northwest
#
#                         1st Most Common Venue        2nd Most Common Venue  \
# 1                                         Bar                  Yoga Studio
# 4                                  Playground                       Lounge
# 5                               Train Station                   Restaurant
# 6                              Discount Store            Convenience Store
# 7                                Intersection                     Bus Line
# 8                              Discount Store               Sandwich Place
# 10                                     Bakery                    Wine Shop
# 11                          Convenience Store                  Auto Garage
# 12                              Shopping Mall                 Skating Rink
# 13                                   Pharmacy                  Pizza Place
# 14                                   Pharmacy                  Yoga Studio
# 15                       Fast Food Restaurant                  Coffee Shop
# 17   Residential Building (Apartment / Condo)                      Dog Run
# 18                             Clothing Store         Fast Food Restaurant
# 21                                       Café            Korean Restaurant
# 22                           Ramen Restaurant         Fast Food Restaurant
# 24                          Convenience Store  Eastern European Restaurant
# 27                              Grocery Store              Bubble Tea Shop
# 29                                Pizza Place                  Coffee Shop
# 31                               Hockey Arena                Grocery Store
# 33                                Pizza Place         Fast Food Restaurant
# 35                                Pizza Place         Fast Food Restaurant
# 36                                   Pharmacy                Grocery Store
# 37                                College Gym                        Trail
# 38                        Sporting Goods Shop                  Coffee Shop
# 39                                Yoga Studio                         Park
# 42                                       Park               Sandwich Place
# 43                                      Diner                         Café
# 44                                   Bus Line                  Swim School
# 45                          Convenience Store                        Hotel
# 47                               Dessert Shop             Toy / Game Store
# 49                         Light Rail Station                  Coffee Shop
# 51                                 Restaurant                  Coffee Shop
# 52                                Coffee Shop          Japanese Restaurant
# 53                                Coffee Shop                       Bakery
# 54                                Coffee Shop               Clothing Store
# 55                                Coffee Shop                         Café
# 56                                Coffee Shop                   Restaurant
# 57                                Coffee Shop               Clothing Store
# 58                                Coffee Shop                         Café
# 60                                Coffee Shop                         Café
# 61                                Coffee Shop                        Hotel
# 62                                Coffee Shop           Italian Restaurant
# 65                             Sandwich Place                         Café
# 66                                       Café                  Coffee Shop
# 67                                       Café                          Bar
# 68                                Coffee Shop           Italian Restaurant
# 69                                Coffee Shop                         Café
# 70                                Coffee Shop                        Hotel
# 71                             Clothing Store       Furniture / Home Store
# 72                                Pizza Place         Fast Food Restaurant
# 73                               Hockey Arena                        Field
# 75                                       Café                Grocery Store
# 76                     Furniture / Home Store                         Park
# 77                                        Bar                  Coffee Shop
# 78                                Coffee Shop                         Café
# 80                       Fast Food Restaurant   Construction & Landscaping
# 81                                    Brewery                 Home Service
# 83                                Coffee Shop  Eastern European Restaurant
# 84                                       Café                  Coffee Shop
# 85                                Coffee Shop               Sandwich Place
# 86                                Coffee Shop                         Café
# 87                                Coffee Shop                         Café
# 88                          Convenience Store               Breakfast Spot
# 89                          Convenience Store                          Pub
# 91                         Italian Restaurant                  Coffee Shop
# 92                              Burrito Place  Eastern European Restaurant
# 93                                   Pharmacy                Grocery Store
# 95                          Electronics Store                 Carpet Store
# 98                          Convenience Store                     Pharmacy
# 99                                Pizza Place                  Coffee Shop
# 100                               Pizza Place                     Bus Line
# 101                             Grocery Store                 Liquor Store
# 102                              Burger Joint             Storage Facility
#
#            3rd Most Common Venue   4th Most Common Venue  \
# 1                           Food             Flower Shop
# 4    Eastern European Restaurant             Flower Shop
# 5                  Grocery Store       Indian Restaurant
# 6               Department Store             Coffee Shop
# 7                         Bakery             Bus Station
# 8                       Pharmacy                    Bank
# 10                     Gift Shop             Yoga Studio
# 11          Fast Food Restaurant    Ethiopian Restaurant
# 12            Chinese Restaurant        Sushi Restaurant
# 13                    Hobby Shop             Golf Course
# 14   Eastern European Restaurant             Flower Shop
# 15            Chinese Restaurant                Pharmacy
# 17                   Yoga Studio    Ethiopian Restaurant
# 18                 Women's Store             Coffee Shop
# 21     Middle Eastern Restaurant            Dessert Shop
# 22                          Café             Coffee Shop
# 24                        Bakery             Coffee Shop
# 27                    Beer Store             Coffee Shop
# 29            Miscellaneous Shop    Fast Food Restaurant
# 31             Convenience Store          Discount Store
# 33                 Shopping Mall           Grocery Store
# 35            Athletics & Sports                    Café
# 36                      Bus Line             Pizza Place
# 37             Health Food Store                     Pub
# 38                    Sports Bar  Furniture / Home Store
# 39                Sandwich Place             Coffee Shop
# 42                     Pet Store      Italian Restaurant
# 43                   Pizza Place      Italian Restaurant
# 44                   Yoga Studio       Electronics Store
# 45                Breakfast Spot                    Park
# 47                   Pizza Place          Sandwich Place
# 49                           Spa            Liquor Store
# 51            Italian Restaurant                  Bakery
# 52                    Restaurant                 Gay Bar
# 53                 Boat or Ferry                 Theater
# 54                Cosmetics Shop    Fast Food Restaurant
# 55                         Hotel              Restaurant
# 56                        Bakery      Seafood Restaurant
# 57                        Bakery                Tea Room
# 58                         Hotel              Steakhouse
# 60                         Hotel                     Bar
# 61                          Café              Restaurant
# 62       Comfort Food Restaurant         Thai Restaurant
# 65                  Burger Joint       Indian Restaurant
# 66                    Restaurant                  Bakery
# 67            Mexican Restaurant      Chinese Restaurant
# 68                           Bar                    Park
# 69                    Steakhouse                   Hotel
# 70                          Café      Seafood Restaurant
# 71              Toy / Game Store       Electronics Store
# 72      Mediterranean Restaurant           Grocery Store
# 73                   Coffee Shop                   Trail
# 75                    Playground      Athletics & Sports
# 76                   Supermarket                     Bar
# 77                    Restaurant            Cocktail Bar
# 78        Furniture / Home Store              Restaurant
# 80                   Coffee Shop                Bus Stop
# 81            Athletics & Sports  Furniture / Home Store
# 83                        Bakery              Restaurant
# 84                        Bakery             Pizza Place
# 85                          Café       College Cafeteria
# 86                    Steakhouse                   Hotel
# 87                    Steakhouse                   Hotel
# 88                    Beer Store                    Bank
# 89                           Gym          Sandwich Place
# 91          Fast Food Restaurant        Sushi Restaurant
# 92               Thai Restaurant                  Buffet
# 93                          Bank           Shopping Mall
# 95             Fish & Chips Shop           Shopping Mall
# 98                         Diner     Fried Chicken Joint
# 99     Middle Eastern Restaurant      Chinese Restaurant
# 100          Arts & Crafts Store             Yoga Studio
# 101          Japanese Restaurant     Fried Chicken Joint
# 102                  Gas Station             Coffee Shop
#
#            5th Most Common Venue   6th Most Common Venue  \
# 1                    Flea Market             Fish Market
# 4                    Flea Market             Fish Market
# 5                    Yoga Studio       Electronics Store
# 6           Fast Food Restaurant             Event Space
# 7                   Soccer Field             Coffee Shop
# 8                   Liquor Store             Coffee Shop
# 10                Farmers Market       Electronics Store
# 11                   Event Space      Falafel Restaurant
# 12                        Bakery          Discount Store
# 13                   Coffee Shop      Chinese Restaurant
# 14                   Flea Market             Fish Market
# 15                 Grocery Store          Sandwich Place
# 17                   Event Space      Falafel Restaurant
# 18                    Food Court         Supplement Shop
# 21                Sandwich Place                Bus Line
# 22                   Pizza Place               Juice Bar
# 24                  Intersection                    Park
# 27                   Supermarket                     Gym
# 29          Caribbean Restaurant  Furniture / Home Store
# 31                   Coffee Shop          Clothing Store
# 33                Discount Store             Coffee Shop
# 35                Breakfast Spot               Gastropub
# 36               Doctor's Office                  Market
# 37   Eastern European Restaurant       Electronics Store
# 38                  Burger Joint               Bike Shop
# 39                  Intersection       Indian Restaurant
# 42                 Burrito Place            Burger Joint
# 43                       Brewery     Arts & Crafts Store
# 44                   Flower Shop             Flea Market
# 45                           Gym          Clothing Store
# 47            Italian Restaurant                    Café
# 49                   Supermarket             Event Space
# 51                          Café             Pizza Place
# 52              Sushi Restaurant             Pizza Place
# 53       Health & Beauty Service                    Café
# 54                          Café                   Diner
# 55                        Bakery          Clothing Store
# 56                      Beer Bar                   Hotel
# 57                     Bookstore      Chinese Restaurant
# 58                           Bar               Gastropub
# 60                    Restaurant      Seafood Restaurant
# 61            Italian Restaurant     Japanese Restaurant
# 62                           Pub              Restaurant
# 65                      Pharmacy             Pizza Place
# 66                           Gym                     Bar
# 67         Vietnamese Restaurant     Dumpling Restaurant
# 68                           Pub       French Restaurant
# 69                           Bar     American Restaurant
# 70                    Restaurant                     Bar
# 71                   Men's Store              Food Court
# 72           Japanese Restaurant      Italian Restaurant
# 73                 Grocery Store                    Park
# 75                   Candy Store      Italian Restaurant
# 76                          Bank                  Bakery
# 77              Asian Restaurant       French Restaurant
# 78                        Bakery          Sandwich Place
# 80          Ethiopian Restaurant             Event Space
# 81                   Event Space      Falafel Restaurant
# 83                     Gift Shop               Bookstore
# 84                  Dance Studio            Liquor Store
# 85            Italian Restaurant               Bookstore
# 86                           Bar     American Restaurant
# 87                           Bar     American Restaurant
# 88                 Grocery Store            Skating Rink
# 89              Cuban Restaurant     Dumpling Restaurant
# 91            Chinese Restaurant             Yoga Studio
# 92                Mattress Store        Storage Facility
# 93                  Skating Rink                    Park
# 95            College Rec Center           Grocery Store
# 98                   Pizza Place             Fish Market
# 99                Sandwich Place            Dance Studio
# 100                        Field             Event Space
# 101                  Coffee Shop              Beer Store
# 102    Middle Eastern Restaurant                     Gym
#
#          7th Most Common Venue      8th Most Common Venue  \
# 1            Fish & Chips Shop        Filipino Restaurant
# 4            Fish & Chips Shop        Filipino Restaurant
# 5         Ethiopian Restaurant                Event Space
# 6           Falafel Restaurant                       Farm
# 7                  Yoga Studio                Event Space
# 8                       Bistro                Yoga Studio
# 10        Ethiopian Restaurant                Event Space
# 11                        Farm             Farmers Market
# 12                 Supermarket        Shanghai Restaurant
# 13               Shopping Mall        Fried Chicken Joint
# 14           Fish & Chips Shop        Filipino Restaurant
# 15                Burger Joint            Bubble Tea Shop
# 17                        Farm             Farmers Market
# 18         Japanese Restaurant          Electronics Store
# 21         Japanese Restaurant                Supermarket
# 22         Japanese Restaurant        Fried Chicken Joint
# 24                    Bus Line        Filipino Restaurant
# 27                Intersection       Fast Food Restaurant
# 29          Falafel Restaurant                        Bar
# 31        Fast Food Restaurant                 Beer Store
# 33          Falafel Restaurant               Liquor Store
# 35                    Bus Line                       Bank
# 36               Metro Station                       Café
# 37        Ethiopian Restaurant                Event Space
# 38                     Brewery          Electronics Store
# 39                      Bridge                Gas Station
# 42        Fast Food Restaurant               Liquor Store
# 43                 Coffee Shop             Sandwich Place
# 44                 Fish Market          Fish & Chips Shop
# 45           Food & Drink Shop          Electronics Store
# 47                 Coffee Shop         Salon / Barbershop
# 49          Falafel Restaurant                       Farm
# 51                      Market        Japanese Restaurant
# 52                         Pub       Fast Food Restaurant
# 53          Italian Restaurant             Breakfast Spot
# 54              Lingerie Store        Japanese Restaurant
# 55          Italian Restaurant         Seafood Restaurant
# 56              Breakfast Spot               Cocktail Bar
# 57                       Plaza        Sporting Goods Shop
# 58                  Restaurant           Asian Restaurant
# 60                   Gastropub        American Restaurant
# 61               Deli / Bodega                  Gastropub
# 62              Sandwich Place                       Café
# 65                         Pub                Coffee Shop
# 66          Italian Restaurant        Japanese Restaurant
# 67                 Coffee Shop               Burger Joint
# 68                   Speakeasy                     Bakery
# 69                         Pub                Pizza Place
# 70               Deli / Bodega           Asian Restaurant
# 71              Cosmetics Shop        American Restaurant
# 72            Sushi Restaurant  Latin American Restaurant
# 73                  Playground        Filipino Restaurant
# 75                  Baby Store                Coffee Shop
# 76        Brazilian Restaurant  Middle Eastern Restaurant
# 77                      Bakery                Men's Store
# 78          Italian Restaurant                Supermarket
# 80          Falafel Restaurant                       Farm
# 81                        Farm             Farmers Market
# 83           Food & Drink Shop            Thai Restaurant
# 84           French Restaurant                  Bookstore
# 85       Portuguese Restaurant        Fried Chicken Joint
# 86                         Pub                Pizza Place
# 87                         Pub                Pizza Place
# 88           Indian Restaurant                      Field
# 89                 Fish Market          Fish & Chips Shop
# 91          Falafel Restaurant          Electronics Store
# 92   Middle Eastern Restaurant         Miscellaneous Shop
# 93                        Café         Falafel Restaurant
# 95                        Farm       Ethiopian Restaurant
# 98           Fish & Chips Shop        Filipino Restaurant
# 99               Deli / Bodega                Fish Market
# 100         Falafel Restaurant                       Farm
# 101                       Park             Sandwich Place
# 102             Sandwich Place        Filipino Restaurant
#
#          9th Most Common Venue       10th Most Common Venue
# 1                        Field         Fast Food Restaurant
# 4                        Field         Fast Food Restaurant
# 5           Falafel Restaurant                         Farm
# 6               Farmers Market                        Field
# 7           Falafel Restaurant                         Farm
# 8                  Event Space           Falafel Restaurant
# 10          Falafel Restaurant                         Farm
# 11                       Field  Eastern European Restaurant
# 12                        Pool              Bubble Tea Shop
# 13             Thai Restaurant            Convenience Store
# 14                       Field         Fast Food Restaurant
# 15                 Pizza Place         Other Great Outdoors
# 17        Fast Food Restaurant  Eastern European Restaurant
# 18                   Juice Bar                     Boutique
# 21                 Coffee Shop             Ramen Restaurant
# 22            Sushi Restaurant                   Steakhouse
# 24                       Field         Fast Food Restaurant
# 27                 Event Space           Falafel Restaurant
# 29                        Bank          Japanese Restaurant
# 31                        Bank                       Bakery
# 33        Caribbean Restaurant          Fried Chicken Joint
# 35                Intersection           Rock Climbing Spot
# 36              Breakfast Spot    Middle Eastern Restaurant
# 37          Falafel Restaurant                         Farm
# 38          Mexican Restaurant                  Record Shop
# 39                       Field         Fast Food Restaurant
# 42          Light Rail Station                   Steakhouse
# 43         American Restaurant             Sushi Restaurant
# 44         Filipino Restaurant                        Field
# 45                 Flea Market                  Fish Market
# 47                  Restaurant                        Diner
# 49              Farmers Market         Fast Food Restaurant
# 51                         Pub           Chinese Restaurant
# 52                 Men's Store                        Hotel
# 53                     Brewery                          Spa
# 54                    Tea Room           Italian Restaurant
# 55                   Gastropub               Cosmetics Shop
# 56                 Cheese Shop                   Steakhouse
# 57              Cosmetics Shop                 Burger Joint
# 58                      Bakery          Japanese Restaurant
# 60          Italian Restaurant                Deli / Bodega
# 61         American Restaurant                   Steakhouse
# 62                     Butcher         Fast Food Restaurant
# 65                  Restaurant   Modern European Restaurant
# 66                   Bookstore        College Arts Building
# 67                        Park                   Donut Shop
# 68                  Restaurant                         Café
# 69            Asian Restaurant             Sushi Restaurant
# 70                      Bakery                    Gastropub
# 71    Mediterranean Restaurant          Sporting Goods Shop
# 72         Rental Car Location                  Gas Station
# 73        Fast Food Restaurant               Farmers Market
# 75          Dim Sum Restaurant                 Dessert Shop
# 76                 Pizza Place                          Gym
# 77                 Pizza Place        Vietnamese Restaurant
# 78                    Beer Bar                          Bar
# 80              Farmers Market                        Field
# 81        Fast Food Restaurant                        Field
# 83            Sushi Restaurant          American Restaurant
# 84   Latin American Restaurant                  Flower Shop
# 85            Sushi Restaurant                   Food Truck
# 86            Asian Restaurant             Sushi Restaurant
# 87            Asian Restaurant             Sushi Restaurant
# 88        Fast Food Restaurant            Electronics Store
# 89         Filipino Restaurant                        Field
# 91        Ethiopian Restaurant                  Event Space
# 92            Sushi Restaurant                  Coffee Shop
# 93        Ethiopian Restaurant                  Event Space
# 95                 Event Space           Falafel Restaurant
# 98                       Field  Eastern European Restaurant
# 99           Fish & Chips Shop          Filipino Restaurant
# 100             Farmers Market         Fast Food Restaurant
# 101                Pizza Place                  Video Store
# 102                      Field         Fast Food Restaurant

# %% [markdown]
# Let's check the most popular venue types:

# %%
print(cluster1[["1st Most Common Venue","PostalCode"]].groupby("1st Most Common Venue").count().sort_values(by="PostalCode",ascending=False).head())
print(cluster1[["2nd Most Common Venue","PostalCode"]].groupby("2nd Most Common Venue").count().sort_values(by="PostalCode",ascending=False).head())
# Out:
#                        PostalCode
# 1st Most Common Venue
# Coffee Shop                    18
# Convenience Store               6
# Pizza Place                     6
# Café                            5
# Pharmacy                        4
#                        PostalCode
# 2nd Most Common Venue
# Coffee Shop                    10
# Café                            9
# Fast Food Restaurant            5
# Grocery Store                   4
# Hotel                           3

# %% [markdown]
# **Cluster 1** - neighborhoods scattered across the city with top concentration in historical center, has lots of coffee shops, convenience stores, pizza places and hotels

# %% [markdown]
# ### Cluster 2

# %%
cluster2 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[0,2] + list(range(6, toronto_merged.shape[1]))]]

cluster2
# Out:
#    PostalCode                                     Neighborhood  \
# 28        M3H  Bathurst Manor, Downsview North, Wilson Heights
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 28           Men's Store           Yoga Studio     Food & Drink Shop
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 28           Flower Shop           Flea Market           Fish Market
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 28     Fish & Chips Shop   Filipino Restaurant                 Field
#
#    10th Most Common Venue
# 28   Fast Food Restaurant

# %% [markdown]
# Cluster 2 - several neighborhoods with lots of men's stores, food and drink shops and Yoga studios

# %% [markdown]
# ### Cluster 3

# %%
cluster3 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[0,2] + list(range(6, toronto_merged.shape[1]))]]

cluster3
# Out:
#    PostalCode       Neighborhood       1st Most Common Venue  \
# 0         M1B     Rouge, Malvern                Home Service
# 32        M3M  Downsview Central  Construction & Landscaping
# 96        M9L      Humber Summit                Home Service
#
#    2nd Most Common Venue       3rd Most Common Venue 4th Most Common Venue  \
# 0      Food & Drink Shop                 Flower Shop           Flea Market
# 32     Food & Drink Shop                 Flower Shop           Flea Market
# 96      Business Service  Construction & Landscaping   American Restaurant
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0            Fish Market     Fish & Chips Shop   Filipino Restaurant
# 32           Fish Market     Fish & Chips Shop   Filipino Restaurant
# 96     Electronics Store                  Food           Flower Shop
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0                  Field  Fast Food Restaurant         Farmers Market
# 32                 Field  Fast Food Restaurant         Farmers Market
# 96           Flea Market           Fish Market      Fish & Chips Shop

# %% [markdown]
# Cluster 3 - several neighborhoods with home service facilities, food and drink, flower shops and fish markets

# %% [markdown]
# ### Cluster 4

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[0,2] + list(range(6, toronto_merged.shape[1]))]]
# Out:
#    PostalCode                                       Neighborhood  \
# 94        M9B  Cloverdale, Islington, Martin Grove, Princess ...
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 94   Filipino Restaurant           Yoga Studio     Food & Drink Shop
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 94           Flower Shop           Flea Market           Fish Market
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 94     Fish & Chips Shop                 Field  Fast Food Restaurant
#
#    10th Most Common Venue
# 94         Farmers Market

# %% [markdown]
# **Cluster 4** - neighborhoods in Etobicoke with several Filipino restaurants, Yoga studios and food&drink shops. These are mostly residential areas.

# %% [markdown]
# ### Cluster 5

# %%
cluster5 = toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[0,2] + list(range(6, toronto_merged.shape[1]))]]

cluster5
# Out:
#    PostalCode                                       Neighborhood  \
# 2         M1E                  Guildwood, Morningside, West Hill
# 3         M1G                                             Woburn
# 9         M1N                        Birch Cliff, Cliffside West
# 19        M2K                                    Bayview Village
# 23        M2P                                    York Mills West
# 25        M3A                                          Parkwoods
# 26        M3B                                    Don Mills North
# 30        M3K                        CFB Toronto, Downsview East
# 34        M4A                                   Victoria Village
# 40        M4J                                       East Toronto
# 41        M4K                       The Danforth West, Riverdale
# 46        M4R                                 North Toronto West
# 48        M4T                        Moore Park, Summerhill East
# 50        M4W                                           Rosedale
# 59        M5J  Harbourfront East, Toronto Islands, Union Station
# 64        M5P                Forest Hill North, Forest Hill West
# 74        M6E                                Caledonia-Fairbanks
# 79        M6L                 Downsview, North Park, Upwood Park
# 82        M6P                      High Park, The Junction South
# 90        M8X      The Kingsway, Montgomery Road, Old Mill North
# 97        M9M                                   Emery, Humberlea
#
#          1st Most Common Venue 2nd Most Common Venue  \
# 2   Construction & Landscaping  Gym / Fitness Center
# 3             Business Service     Korean Restaurant
# 9        General Entertainment       College Stadium
# 19  Construction & Landscaping               Dog Run
# 23           Convenience Store             Speakeasy
# 25           Food & Drink Shop              Bus Stop
# 26                Burger Joint           Gas Station
# 30                  Food Court                  Park
# 34                  Food Stand         Grocery Store
# 40                         Bar                  Park
# 41                        Park              Bus Line
# 46                  Playground                Garden
# 48                Tennis Court                   Gym
# 50                  Playground           Candy Store
# 59                        Pier       Harbor / Marina
# 64                Home Service                Lawyer
# 74                        Park    Mexican Restaurant
# 79                        Park      Basketball Court
# 82                Intersection                  Park
# 90                        Park           Yoga Studio
# 97                 Coffee Shop                  Park
#
#           3rd Most Common Venue 4th Most Common Venue  \
# 2                          Park  Ethiopian Restaurant
# 3                  Soccer Field           Coffee Shop
# 9                  Skating Rink                  Park
# 19                        Trail                  Park
# 23                         Bank                  Park
# 25                         Park  Fast Food Restaurant
# 26                 Soccer Field                  Park
# 30                      Airport           Coffee Shop
# 34                         Park           Yoga Studio
# 40           Italian Restaurant        Farmers Market
# 41               Discount Store         Grocery Store
# 46                         Park              Gym Pool
# 48                         Park            Playground
# 50                         Park         Grocery Store
# 59                         Park           Yoga Studio
# 64                         Park        Farmers Market
# 74                       Bakery  Fast Food Restaurant
# 79                       Bakery  Ethiopian Restaurant
# 82                  Yoga Studio        Farmers Market
# 90  Eastern European Restaurant           Flower Shop
# 97                    Nightclub           Yoga Studio
#
#           5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 2                   Event Space    Falafel Restaurant                  Farm
# 3                          Park  Fast Food Restaurant           Event Space
# 9                      Gym Pool                   Gym  Fast Food Restaurant
# 19  Eastern European Restaurant  Ethiopian Restaurant           Event Space
# 23                  Flea Market           Fish Market     Fish & Chips Shop
# 25         Ethiopian Restaurant           Event Space    Falafel Restaurant
# 26                  Yoga Studio        Farmers Market  Ethiopian Restaurant
# 30         Ethiopian Restaurant           Event Space    Falafel Restaurant
# 34               Farmers Market  Ethiopian Restaurant           Event Space
# 40                  Fish Market     Fish & Chips Shop   Filipino Restaurant
# 41                  Yoga Studio  Ethiopian Restaurant           Event Space
# 46                         Farm     Electronics Store  Ethiopian Restaurant
# 48             Cuban Restaurant          Cupcake Shop           Flea Market
# 50           Falafel Restaurant     Electronics Store  Ethiopian Restaurant
# 59               Farmers Market     Electronics Store  Ethiopian Restaurant
# 64         Ethiopian Restaurant           Event Space    Falafel Restaurant
# 74                          Gym                Market         Women's Store
# 79                  Event Space    Falafel Restaurant                  Farm
# 82         Ethiopian Restaurant           Event Space    Falafel Restaurant
# 90                  Flea Market           Fish Market     Fish & Chips Shop
# 97                         Farm     Electronics Store  Ethiopian Restaurant
#
#    8th Most Common Venue 9th Most Common Venue       10th Most Common Venue
# 2         Farmers Market  Fast Food Restaurant  Eastern European Restaurant
# 3     Falafel Restaurant                  Farm               Farmers Market
# 9                  Field        Farmers Market                   Donut Shop
# 19    Falafel Restaurant                  Farm               Farmers Market
# 23   Filipino Restaurant                 Field  Eastern European Restaurant
# 25                  Farm        Farmers Market                        Field
# 26           Event Space    Falafel Restaurant                         Farm
# 30                  Farm        Farmers Market         Fast Food Restaurant
# 34    Falafel Restaurant                  Farm         Fast Food Restaurant
# 40                 Field  Fast Food Restaurant          Dumpling Restaurant
# 41    Falafel Restaurant                  Farm               Farmers Market
# 46           Event Space    Falafel Restaurant               Farmers Market
# 48           Fish Market     Fish & Chips Shop          Filipino Restaurant
# 50           Event Space                  Farm          Dumpling Restaurant
# 59           Event Space    Falafel Restaurant                         Farm
# 64                  Farm  Fast Food Restaurant  Eastern European Restaurant
# 74   Sporting Goods Shop            Beer Store                  Fish Market
# 79        Farmers Market  Fast Food Restaurant                  Yoga Studio
# 82                  Farm  Fast Food Restaurant  Eastern European Restaurant
# 90   Filipino Restaurant                 Field         Fast Food Restaurant
# 97           Event Space    Falafel Restaurant               Farmers Market

# %%
print(cluster5[["1st Most Common Venue","PostalCode"]].groupby("1st Most Common Venue").count().sort_values(by="PostalCode",ascending=False).head(5))
print(cluster5[["2nd Most Common Venue","PostalCode"]].groupby("2nd Most Common Venue").count().sort_values(by="PostalCode",ascending=False).head(5))
# Out:
#                             PostalCode
# 1st Most Common Venue
# Park                                 4
# Construction & Landscaping           2
# Playground                           2
# Bar                                  1
# Burger Joint                         1
#                        PostalCode
# 2nd Most Common Venue
# Park                            4
# Basketball Court                1
# Bus Line                        1
# Speakeasy                       1
# Mexican Restaurant              1

# %% [markdown]
# **Cluster 5** - neighborhoods with lots of parks, playgrounds and sport facilities, construction and landscaping businesses and some restaurants are available in these neighborhoods.

# %% [markdown]
# ### Cluster 6

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 5, toronto_merged.columns[[0,2] + list(range(6, toronto_merged.shape[1]))]]
# Out:
#    PostalCode              Neighborhood 1st Most Common Venue  \
# 16        M1X               Upper Rouge                   NaN
# 20        M2L  Silver Hills, York Mills                   NaN
# 63        M5N                  Roselawn                   NaN
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 16                   NaN                   NaN                   NaN
# 20                   NaN                   NaN                   NaN
# 63                   NaN                   NaN                   NaN
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 16                   NaN                   NaN                   NaN
# 20                   NaN                   NaN                   NaN
# 63                   NaN                   NaN                   NaN
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 16                   NaN                   NaN                    NaN
# 20                   NaN                   NaN                    NaN
# 63                   NaN                   NaN                    NaN

# %% [markdown]
# **Cluster 6** - are mostly residential areas or less developed areas which we cannot tell much without some additional research.
#
# Quick overview:<br/>
# - Silver Hills - quiet residential area with mid+ price range<br/>
# - York Mills - residential area with luxury condos and detached houses with mid to high price range<br/>
# - Roselawn - residential area with mostly detached houses<br/>
# - Rouge National Urban Park located within this cluster.
